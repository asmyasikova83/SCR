# %%
import mne
import os
import os.path as op
import numpy as np
import pandas as  pd
import matplotlib.pyplot as plt

# %%
# %matplotlib qt

# %%
event_id = {'Sound_Cfg_Minus_A' : 2,  
        	'Pictu_Cfg_Minus_A' : 4,
        	'Compl_Cfg_Plus__AR' : 7,
        	'Sound_Elm_Plus__AR' : 9,
        	'Pictu_Elm_Minus_A' : 10,
        	'Compl_Elm_Minus_A' : 12
           }
styles = {  
        'Sound_Elm_Plus__AR' : {"color": 'red'}, 
        'Pictu_Cfg_Minus_A' : {"color": 'cyan'},
        'Compl_Elm_Minus_A' : {"color": 'plum'}, 
        'Sound_Cfg_Minus_A' : {"color": 'pink'}, 
        'Pictu_Elm_Minus_A' : {"color": 'greenyellow'},
        'Compl_Cfg_Plus__AR' : {"color": 'magenta'}} 
styles1 = {  
        'Compl_Elm_Minus_A' : {"color": 'cyan'}, 
        'Compl_Cfg_Plus__AR' : {"color": 'red'}} 
styles2 = {  
        'Sound_Cfg_Minus_A' : {"color": 'green'}, 
        'Sound_Elm_Plus__AR' : {"color": 'orange'}}

# %%
#all event_id dictionaries
tok 130 140 132 134 136 138

# %%
a = ('a', {'Sound_Elm_Plus__AR' : 3,
        	'Pictu_Elm_Minus_A' : 4,
        	'Compl_Elm_Minus_A' : 6,
        	'Sound_Cfg_Minus_A' : 8,
        	'Pictu_Cfg_Minus_A' : 10,
        	'Compl_Cfg_Plus__AR' : 13})

b = ('b', {'Sound_Elm_Minus_A' : 2,  
        	'Pictu_Elm_Plus__AR' : 5,
        	'Compl_Elm_Minus_A' : 6,
        	'Sound_Cfg_Minus_A' : 8,
        	'Pictu_Cfg_Minus_A' : 10,
        	'Compl_Cfg_Plus__AR' : 13,
})

c = ('c', {'Sound_Cfg_Minus_A' : 2,  
        	'Pictu_Cfg_Minus_A' : 4,
        	'Compl_Cfg_Plus__AR' : 7,
        	'Sound_Elm_Plus__AR' : 9,
        	'Pictu_Elm_Minus_A' : 10,
        	'Compl_Elm_Minus_A' : 12})
                
d = ('d', {'Sound_Cfg_Minus_A' : 2,  
        	'Pictu_Cfg_Minus_A' : 4,
        	'Compl_Cfg_Plus__AR' : 7,
        	'Sound_Elm_Minus_A' : 8,
        	'Pictu_Elm_Plus__AR' : 11,
        	'Compl_Elm_Minus_A' : 12})

# %%
c = ('c', {'Sound_Cfg_Minus_A' : 2,  
        	'Pictu_Cfg_Minus_A' : 4,
        	'Compl_Cfg_Plus__AR' : 7,
        	'Sound_Elm_Plus__AR' : 9,
        	'Pictu_Elm_Minus_A' : 10,
        	'Compl_Elm_Minus_A' : 12})

# %%
#ячейки с испытуемыми, датами и контрбалансировочной группой

# %%
subjs = (('W001', 230704, a),
('W002', 230712, b),
('W003', 230719, c),
('W004', 230717, d),
('W005', 230721, a),
('W006', 230728, b),
('W007', 230731, c),
('W008', 230731, d),
('W009',  230811, a),
('W010',  230811, b),
('W011',  230814, c),
('W012',  230816, d),
('W013',  230823, a),
('W014',  230831, b),
('W015',  230828, c))

# %%
subjs = (('W001', 230628, a),
('W002', 230704, b),
('W003', 230710, c),
('W004', 230711, d),
('W005', 230714, a),
('W006', 230718, b),
('W007', 230722, c),
('W008', 230724, d),
('W009',  230804, a),
('W010',  230804, b),
('W011',  230807, c),
('W012',  230809, d),
('W013',  230816, a),
('W014',  230821, b),
('W015',  230821, c))

# %%
for subj in subjs:
    path = f"E:/MSUPE/piansrann/meg/{subj[0]}/{subj[1]}/"
    files = os.listdir(path)
    for file in files:
        print(file)
# Out:
# W001_a_2_run2_raw_tsss.fif
# W001_er_raw_bads.fif
# W001_a_2_run4_raw_tsss.fif
# W001_a_2_run1_raw_tsss.fif
# W001_a_2_run6_raw_tsss.fif
# W001_a_2_run3_raw_tsss.fif
# W001_2_rest_raw_tsss_mc.fif
# W001_a_2_run5_raw_tsss.fif
# RAW
# LOGS
# W002_er_raw_bads.fif
# W002_b_2_run6_raw_tsss.fif
# W002_b_2_run1_raw_tsss.fif
# W002_b_2_run2_raw_tsss.fif
# W002_2_rest_raw_tsss.fif
# W002_b_2_run4_raw_tsss.fif
# W002_b_2_run5_raw_tsss.fif
# RAW
# LOGS
# W002_b_2_run3_raw_tsss.fif
# W003_c_2_run4_raw_tsss.fif
# W003_c_2_run6_raw_tsss.fif
# W003_c_2_run3_raw_tsss.fif
# W003_2_rest_raw_tsss_mc.fif
# W003_c_2_run2_raw_tsss.fif
# W003_c_2_run1_raw_tsss.fif
# W003_c_2_run5_raw_tsss.fif
# W003_er_raw_bads.fif
# RAW
# LOGS
# W004_d_2_run1_raw_tsss.fif
# W004_2_rest_raw_tsss_mc.fif
# W004_d_2_run3_raw_tsss.fif
# W004_d_2_run5_raw_tsss.fif
# W004_d_2_run2_raw_tsss.fif
# W004_d_2_run4_raw_tsss.fif
# W004_er_raw_bads.fif
# W004_d_2_run6_raw_tsss.fif
# RAW
# LOGS
# W005_a_2_run6_raw_tsss.fif
# W005_2_rest_raw_tsss_mc.fif
# W005_a_2_run4_raw_tsss.fif
# W005_a_2_run3_raw_tsss.fif
# W005_a_2_run5_raw_tsss.fif
# W005_er_raw_bads.fif
# W005_a_2_run2_raw_tsss.fif
# W005_a_2_run1_raw_tsss.fif
# RAW
# LOGS
# W006_b_2_run5_raw_tsss.fif
# W006_b_2_run1_raw_tsss.fif
# W006_b_2_run6_raw_tsss.fif
# W006_er_raw_bads.fif
# W006_b_2_run2_raw_tsss.fif
# W006_2_rest_raw_tsss_mc.fif
# W006_b_2_run4_raw_tsss.fif
# W006_b_2_run3_raw_tsss.fif
# RAW
# LOGS
# W007_er_raw_bads.fif
# W007_c_2_run4_raw_tsss.fif
# W007_c_2_run6_raw_tsss.fif
# W007_c_2_run1_raw_tsss.fif
# W007_c_2_run2_raw_tsss.fif
# W007_2_rest_raw_tsss_mc.fif
# W007_c_2_run5_raw_tsss.fif
# W007_c_2_run3_raw_tsss.fif
# RAW
# LOGS
# W008_d_2_run6_raw_tsss.fif
# W008_er_raw_bads.fif
# W008_d_2_run4_raw_tsss.fif
# W008_d_2_run1_raw_tsss.fif
# W008_d_2_run3_raw_tsss.fif
# W008_d_2_run2_raw_tsss.fif
# W008_d_2_run5_raw_tsss.fif
# W008_2_rest_raw_tsss_mc.fif
# RAW
# LOGS
# W009_a_2_run5_raw_tsss.fif
# W009_a_2_run1_raw_tsss.fif
# W009_er_raw_bads.fif
# W009_a_2_run6_raw_tsss.fif
# W009_a_2_run3_raw_tsss.fif
# W009_2_rest_raw_tsss_mc.fif
# W009_a_2_run2_raw_tsss.fif
# W009_a_2_run4_raw_tsss.fif
# RAW
# LOGS
# W009_a_2_run1_nosound_.fif
# W010_b_2_run2_raw_tsss.fif
# W010_er_raw_bads.fif
# W010_b_2_run1_raw_tsss.fif
# W010_b_2_run6_raw_tsss.fif
# W010_2_rest_raw_tsss_mc.fif
# W010_b_2_run5_raw_tsss.fif
# W010_b_2_run4_raw_tsss.fif
# W010_b_2_run3_raw_tsss.fif
# RAW
# LOGS
# W011_c_2_run6_raw_tsss.fif
# W011_c_2_run4_raw_tsss.fif
# W011_c_2_run2_raw_tsss.fif
# W011_c_2_run5_raw_tsss.fif
# W011_c_2_run1_raw_tsss.fif
# W011_er_raw_bads.fif
# W011_c_2_run3_raw_tsss.fif
# W011_2_rest_raw_tsss_mc.fif
# RAW
# LOGS
# W012_d_2_run3_raw_tsss.fif
# W012_d_2_run1_raw_tsss.fif
# W012_d_2_run4_raw_tsss.fif
# W012_d_2_run2_raw_tsss.fif
# W012_d_2_run5_raw_tsss.fif
# W012_er_raw_bads.fif
# W012_2_rest_raw_tsss_mc.fif
# W012_d_2_run6_raw_tsss.fif
# RAW
# LOGS
# W013_a_2_run2_raw_tsss.fif
# W013_a_2_run4_raw_tsss.fif
# W013_a_2_run3_raw_tsss.fif
# W013_a_2_run1_raw_tsss.fif
# W013_er_raw_bads.fif
# W013_2_rest_raw_tsss_mc.fif
# W013_a_2_run5_raw_tsss.fif
# W013_a_2_run6_raw_tsss.fif
# RAW
# LOGS
# W014_b_2_run1_raw_tsss.fif
# W014_2_rest_raw_tsss_mc.fif
# W014_b_2_run4_raw_tsss.fif
# W014_b_2_run5_raw_tsss.fif
# W014_2_rest_sleep_raw_tsss_mc.fif
# W014_b_2_run2_raw_tsss.fif
# W014_b_2_run3_raw_tsss.fif
# W014_b_2_run6_raw_tsss.fif
# W014_er_raw_bads.fif
# RAW
# LOGS
# W015_c_2_run1_raw_tsss.fif
# W015_c_2_run6_raw_tsss.fif
# W015_c_2_run5_raw_tsss.fif
# W015_er_raw_bads.fif
# W015_c_2_run3_raw_tsss.fif
# W015_c_2_run2_raw_tsss.fif
# W015_c_2_rest_raw_tsss_mc.fif
# W015_c_2_run4_raw_tsss.fif
# RAW
# LOGS

# %%
#эта ячейка чтобы привыести файлы к названиям, с которыми работает mne
for subj in subjs:
    path = f"E:/MSUPE/piansrann/meg/{subj[0]}/{subj[1]}/"
    files = os.listdir(path)
    for file in files:
        try:
            if file[9:12] == 'run':
                os.rename(path+file, path +file[0: 22] + '.fif')
        except (FileExistsError):
             print(':_)')

# %%
# вот так работает выгрузка эпох в таблицу
df1 = epochs1.to_data_frame()
df1
# Out:
#         time           condition  epoch   MISC001
# 0     -1.000  Sound_Elm_Plus__AR      0  0.204468
# 1     -0.999  Sound_Elm_Plus__AR      0  0.204468
# 2     -0.998  Sound_Elm_Plus__AR      0  0.204163
# 3     -0.997  Sound_Elm_Plus__AR      0  0.203857
# 4     -0.996  Sound_Elm_Plus__AR      0  0.203857
# ...      ...                 ...    ...       ...
# 60055 -0.004   Sound_Cfg_Minus_A     59  0.208130
# 60056 -0.003   Sound_Cfg_Minus_A     59  0.207825
# 60057 -0.002   Sound_Cfg_Minus_A     59  0.207520
# 60058 -0.001   Sound_Cfg_Minus_A     59  0.207520
# 60059  0.000   Sound_Cfg_Minus_A     59  0.207825
#
# [60060 rows x 4 columns]

# %%
# собственно основной цикл (у меня отдельно для первого дня и в следующей ячейке для второго) А дальше идет просто работа с таблицами

# %%
for subj in subjs:

    df = pd.DataFrame(columns=['subject', 'run',  'MISC001'])
    
    for i in range(1, 4):
        prot = subj[2]###
        subject = subj[0]
        path = f"E:/MSUPE/piansrann/meg/{subj[0]}/{subj[1]}/" ###
        run = i
        day = '2'
        file = f'{subject}_{prot[0]}_{day}_run{run}_raw_tsss.fif'  #####
        filename = path+file
        raw = mne.io.read_raw_fif(filename, preload=True)
        pivot_channels = mne.pick_types(raw.info, meg=False, eeg=False, stim=True, eog=False, misc=True)
        channels_of_interest = ['MISC001']
        channels_to_keep = [ch for ch in pivot_channels if raw.info['ch_names'][ch] in channels_of_interest]

        # Extract the data for the selected channels
        for_scr = raw.copy().pick_channels([raw.info['ch_names'][ch] for ch in channels_to_keep])
        #events
        events = mne.find_events(raw, min_duration=0, shortest_event = 0 )
        exclude=[1, 16, 32, 64, 128] #exclusion of event we do not need for further analysis ###############
        events = mne.pick_events(events, include=None, exclude=exclude, step=False)
        events_clean =[]
        tok = [130, 140, 132, 134, 136, 138]
        for i in range(0, len(events[:, 2])-3):
            if events[:, 2][i] == events[:, 2][i+2] or events[:, 2][i+2] in tok:
                events_clean.append(events[i])
        events_clean.append(events[len(events[:, 2])-3])
        events_clean = np.array(events_clean)
        if prot == b:
            for i in range(len(events_clean)):
                if events_clean[:, 2][i] == 12:
                    events_clean[:, 2][i] = 13
                if events_clean[:, 2][i] == 4:
                    events_clean[:, 2][i] = 5

        #epochs 
        epochs1 = mne.Epochs(for_scr, events_clean, picks=['MISC001'], event_id = prot[1], tmin=-1, tmax=0, baseline=None, detrend = None, preload = True, reject_by_annotation = True,  on_missing='ignore')
        df1 = epochs1.to_data_frame()
        result1 = df1.groupby(["epoch", "condition"])['MISC001'].mean()
        result1 = result1.droplevel('epoch')
        result1 = result1.to_frame()
        result1.insert (0, 'run', run)
        result1.insert (0, 'subject', subject)
        result1.insert (0, 'time', '-1 - 0')
        result1.insert (0, 'prot', prot[0])
        
        epochs2 = mne.Epochs(for_scr, events_clean, picks=['MISC001'], event_id = prot[1], tmin=0.970, tmax=1.97, baseline=None, detrend = None, preload = True, reject_by_annotation = True,  on_missing='ignore')
        df2 = epochs2.to_data_frame()
        result2 = df2.groupby(["epoch", "condition"])['MISC001'].mean()
        result2 = result2.to_frame()
        result2 = result2.droplevel('epoch')
        result2.insert (0, 'run', run)
        result2.insert (0, 'subject', subject)
        result2.insert (0, 'time', '0.97 - 1.97')
        result2.insert (0, 'prot', prot[0])

        epochs3 = mne.Epochs(for_scr, events_clean, picks=['MISC001'], event_id = prot[1], tmin=2.94, tmax=3.94, baseline=None, detrend = None, preload = True, reject_by_annotation = True,  on_missing='ignore')
        df3 = epochs3.to_data_frame()
        result3 = df3.groupby(["epoch", "condition"])['MISC001'].mean()
        result3 = result3.to_frame()
        result3 = result3.droplevel('epoch')
        result3.insert (0, 'run', run)
        result3.insert (0, 'subject', subject)
        result3.insert (0, 'time', '2.94 - 3.94')
        result3.insert (0, 'prot', prot[0])

        test = pd.concat([result1, result2, result3], axis=0)
        df = pd.concat([df, test], axis=0)
        df.to_csv(f'E:/MSUPE/piansrann/tables/2/{subject}.csv')
# Out:
# Opening raw data file E:/MSUPE/piansrann/meg/W001/230704/W001_a_2_run1_raw_tsss.fif...
#     Range : 277000 ... 852999 =    277.000 ...   852.999 secs
# Ready.
# Reading 0 ... 575999  =      0.000 ...   575.999 secs...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# 441 events found
# Event IDs: [  1   3   4   6   8  10  13  16  32  64 128 130 140]
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1001 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1001 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1001 original time points ...
# 0 bad epochs dropped
# Opening raw data file E:/MSUPE/piansrann/meg/W001/230704/W001_a_2_run2_raw_tsss.fif...
#     Range : 66000 ... 643999 =     66.000 ...   643.999 secs
# Ready.
# Reading 0 ... 577999  =      0.000 ...   577.999 secs...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# 441 events found
# Event IDs: [  1   3   4   6   8  10  13  16  32  64 128 130 140]
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1001 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1001 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1001 original time points ...
# 0 bad epochs dropped
# Opening raw data file E:/MSUPE/piansrann/meg/W001/230704/W001_a_2_run3_raw_tsss.fif...
#     Range : 106000 ... 707999 =    106.000 ...   707.999 secs
# Ready.
# Reading 0 ... 601999  =      0.000 ...   601.999 secs...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# 441 events found
# Event IDs: [  1   3   4   6   8  10  13  16  64 128 130 140]
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1001 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1001 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1001 original time points ...
# 0 bad epochs dropped
# Opening raw data file E:/MSUPE/piansrann/meg/W002/230712/W002_b_2_run1_raw_tsss.fif...
#     Range : 390000 ... 954999 =    390.000 ...   954.999 secs
# Ready.
# Reading 0 ... 564999  =      0.000 ...   564.999 secs...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# 440 events found
# Event IDs: [  1   2   5   6   8  10  13  16  32  64 128 132 140]
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1001 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1001 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1001 original time points ...
# 0 bad epochs dropped
# Opening raw data file E:/MSUPE/piansrann/meg/W002/230712/W002_b_2_run2_raw_tsss.fif...
#     Range : 80000 ... 657999 =     80.000 ...   657.999 secs
# Ready.
# Reading 0 ... 577999  =      0.000 ...   577.999 secs...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# 441 events found
# Event IDs: [  1   2   4   6   8  10  12  16  32  64 128 132 140]
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1001 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1001 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1001 original time points ...
# 0 bad epochs dropped
# Opening raw data file E:/MSUPE/piansrann/meg/W002/230712/W002_b_2_run3_raw_tsss.fif...
#     Range : 73000 ... 725999 =     73.000 ...   725.999 secs
# Ready.
# Reading 0 ... 652999  =      0.000 ...   652.999 secs...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# 442 events found
# Event IDs: [  1   2   5   6   8  10  13  16  32  64 128 132 140]
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1001 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1001 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1001 original time points ...
# 0 bad epochs dropped
# Opening raw data file E:/MSUPE/piansrann/meg/W003/230719/W003_c_2_run1_raw_tsss.fif...
#     Range : 390000 ... 1010999 =    390.000 ...  1010.999 secs
# Ready.
# Reading 0 ... 620999  =      0.000 ...   620.999 secs...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# 441 events found
# Event IDs: [  1   2   4   7   9  10  12  16  32  64 128 134 136]
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1001 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1001 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1001 original time points ...
# 0 bad epochs dropped
# Opening raw data file E:/MSUPE/piansrann/meg/W003/230719/W003_c_2_run2_raw_tsss.fif...
#     Range : 84000 ... 660999 =     84.000 ...   660.999 secs
# Ready.
# Reading 0 ... 576999  =      0.000 ...   576.999 secs...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# 441 events found
# Event IDs: [  1   2   4   7   9  10  12  16  64 128 134 136]
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1001 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1001 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1001 original time points ...
# 0 bad epochs dropped
# Opening raw data file E:/MSUPE/piansrann/meg/W003/230719/W003_c_2_run3_raw_tsss.fif...
#     Range : 68000 ... 650999 =     68.000 ...   650.999 secs
# Ready.
# Reading 0 ... 582999  =      0.000 ...   582.999 secs...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# 441 events found
# Event IDs: [  1   2   4   7   9  10  12  16  64 128 134 136]
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1001 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1001 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1001 original time points ...
# 0 bad epochs dropped
# Opening raw data file E:/MSUPE/piansrann/meg/W004/230717/W004_d_2_run1_raw_tsss.fif...
#     Range : 52000 ... 610999 =     52.000 ...   610.999 secs
# Ready.
# Reading 0 ... 558999  =      0.000 ...   558.999 secs...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# 440 events found
# Event IDs: [  1   2   4   7   8  11  12  16  64 128 134 138]
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1001 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1001 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1001 original time points ...
# 0 bad epochs dropped
# Opening raw data file E:/MSUPE/piansrann/meg/W004/230717/W004_d_2_run2_raw_tsss.fif...
#     Range : 210000 ... 795999 =    210.000 ...   795.999 secs
# Ready.
# Reading 0 ... 585999  =      0.000 ...   585.999 secs...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# 440 events found
# Event IDs: [  1   2   4   7   8  11  12  16  64 128 134 138]
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1001 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1001 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1001 original time points ...
# 0 bad epochs dropped
# Opening raw data file E:/MSUPE/piansrann/meg/W004/230717/W004_d_2_run3_raw_tsss.fif...
#     Range : 74000 ... 692999 =     74.000 ...   692.999 secs
# Ready.
# Reading 0 ... 618999  =      0.000 ...   618.999 secs...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# 440 events found
# Event IDs: [  1   2   4   7   8  11  12  16  64 128 134 138]
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1001 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1001 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1001 original time points ...
# 0 bad epochs dropped
# Opening raw data file E:/MSUPE/piansrann/meg/W005/230721/W005_a_2_run1_raw_tsss.fif...
#     Range : 477000 ... 1077999 =    477.000 ...  1077.999 secs
# Ready.
# Reading 0 ... 600999  =      0.000 ...   600.999 secs...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# 439 events found
# Event IDs: [  1   3   4   6   8  10  13  16  32  64 128 130 140]
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1001 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1001 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1001 original time points ...
# 0 bad epochs dropped
# Opening raw data file E:/MSUPE/piansrann/meg/W005/230721/W005_a_2_run2_raw_tsss.fif...
#     Range : 187000 ... 807999 =    187.000 ...   807.999 secs
# Ready.
# Reading 0 ... 620999  =      0.000 ...   620.999 secs...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# 440 events found
# Event IDs: [  1   3   4   6   8  10  13  16  64 128 130 140]
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1001 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1001 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1001 original time points ...
# 0 bad epochs dropped
# Opening raw data file E:/MSUPE/piansrann/meg/W005/230721/W005_a_2_run3_raw_tsss.fif...
#     Range : 52000 ... 654999 =     52.000 ...   654.999 secs
# Ready.
# Reading 0 ... 602999  =      0.000 ...   602.999 secs...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# 440 events found
# Event IDs: [  1   3   4   6   8  10  13  16  64 128 130 140]
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1001 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1001 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1001 original time points ...
# 0 bad epochs dropped
# Opening raw data file E:/MSUPE/piansrann/meg/W006/230728/W006_b_2_run1_raw_tsss.fif...
#     Range : 765000 ... 1409999 =    765.000 ...  1409.999 secs
# Ready.
# Reading 0 ... 644999  =      0.000 ...   644.999 secs...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# 441 events found
# Event IDs: [  1   2   5   6   8  10  13  16  64 128 132 140]
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1001 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1001 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1001 original time points ...
# 0 bad epochs dropped
# Opening raw data file E:/MSUPE/piansrann/meg/W006/230728/W006_b_2_run2_raw_tsss.fif...
#     Range : 99000 ... 684999 =     99.000 ...   684.999 secs
# Ready.
# Reading 0 ... 585999  =      0.000 ...   585.999 secs...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# 441 events found
# Event IDs: [  1   2   4   6   8  10  12  16  64 128 132 140]
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1001 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1001 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1001 original time points ...
# 0 bad epochs dropped
# Opening raw data file E:/MSUPE/piansrann/meg/W006/230728/W006_b_2_run3_raw_tsss.fif...
#     Range : 58000 ... 659999 =     58.000 ...   659.999 secs
# Ready.
# Reading 0 ... 601999  =      0.000 ...   601.999 secs...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# 441 events found
# Event IDs: [  1   2   5   6   8  10  13  16  64 128 132 140]
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1001 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1001 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1001 original time points ...
# 0 bad epochs dropped
# Opening raw data file E:/MSUPE/piansrann/meg/W007/230731/W007_c_2_run1_raw_tsss.fif...
#     Range : 125000 ... 725999 =    125.000 ...   725.999 secs
# Ready.
# Reading 0 ... 600999  =      0.000 ...   600.999 secs...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# 441 events found
# Event IDs: [  1   2   4   7   9  10  12  16  64 128 134 136]
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1001 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1001 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1001 original time points ...
# 0 bad epochs dropped
# Opening raw data file E:/MSUPE/piansrann/meg/W007/230731/W007_c_2_run2_raw_tsss.fif...
#     Range : 43000 ... 656999 =     43.000 ...   656.999 secs
# Ready.
# Reading 0 ... 613999  =      0.000 ...   613.999 secs...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# 440 events found
# Event IDs: [  1   2   4   7   9  10  12  16  64 128 134 136]
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1001 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1001 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1001 original time points ...
# 0 bad epochs dropped
# Opening raw data file E:/MSUPE/piansrann/meg/W007/230731/W007_c_2_run3_raw_tsss.fif...
#     Range : 30000 ... 634999 =     30.000 ...   634.999 secs
# Ready.
# Reading 0 ... 604999  =      0.000 ...   604.999 secs...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# 440 events found
# Event IDs: [  1   2   4   7   9  10  12  16  64 128 134 136]
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1001 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1001 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1001 original time points ...
# 0 bad epochs dropped
# Opening raw data file E:/MSUPE/piansrann/meg/W008/230731/W008_d_2_run1_raw_tsss.fif...
#     Range : 321000 ... 948999 =    321.000 ...   948.999 secs
# Ready.
# Reading 0 ... 627999  =      0.000 ...   627.999 secs...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# 440 events found
# Event IDs: [  1   2   4   7   8  11  12  16  32  64 128 134 138]
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1001 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1001 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1001 original time points ...
# 0 bad epochs dropped
# Opening raw data file E:/MSUPE/piansrann/meg/W008/230731/W008_d_2_run2_raw_tsss.fif...
#     Range : 46000 ... 595999 =     46.000 ...   595.999 secs
# Ready.
# Reading 0 ... 549999  =      0.000 ...   549.999 secs...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# 440 events found
# Event IDs: [  1   2   4   7   8  11  12  16  64 128 134 138]
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1001 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1001 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1001 original time points ...
# 0 bad epochs dropped
# Opening raw data file E:/MSUPE/piansrann/meg/W008/230731/W008_d_2_run3_raw_tsss.fif...
#     Range : 22000 ... 575999 =     22.000 ...   575.999 secs
# Ready.
# Reading 0 ... 553999  =      0.000 ...   553.999 secs...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# 441 events found
# Event IDs: [  1   2   4   7   8  11  12  16  64 128 134 138]
# Not setting metadata
# 62 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 62 events and 1001 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 62 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 62 events and 1001 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 62 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 62 events and 1001 original time points ...
# 0 bad epochs dropped
# Opening raw data file E:/MSUPE/piansrann/meg/W009/230811/W009_a_2_run1_raw_tsss.fif...
#     Range : 50000 ... 658999 =     50.000 ...   658.999 secs
# Ready.
# Reading 0 ... 608999  =      0.000 ...   608.999 secs...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# 440 events found
# Event IDs: [  1   3   4   6   8  10  13  16  32  64 128 130 140]
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1001 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1001 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1001 original time points ...
# 0 bad epochs dropped
# Opening raw data file E:/MSUPE/piansrann/meg/W009/230811/W009_a_2_run2_raw_tsss.fif...
#     Range : 59000 ... 688999 =     59.000 ...   688.999 secs
# Ready.
# Reading 0 ... 629999  =      0.000 ...   629.999 secs...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# 441 events found
# Event IDs: [  1   3   4   6   8  10  13  16  64 128 130 140]
# Not setting metadata
# 61 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 61 events and 1001 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 61 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 61 events and 1001 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 61 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 61 events and 1001 original time points ...
# 0 bad epochs dropped
# Opening raw data file E:/MSUPE/piansrann/meg/W009/230811/W009_a_2_run3_raw_tsss.fif...
#     Range : 23000 ... 572999 =     23.000 ...   572.999 secs
# Ready.
# Reading 0 ... 549999  =      0.000 ...   549.999 secs...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# 440 events found
# Event IDs: [  1   3   4   6   8  10  13  16  64 128 130 140]
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1001 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1001 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1001 original time points ...
# 0 bad epochs dropped
# Opening raw data file E:/MSUPE/piansrann/meg/W010/230811/W010_b_2_run1_raw_tsss.fif...
#     Range : 409000 ... 1041999 =    409.000 ...  1041.999 secs
# Ready.
# Reading 0 ... 632999  =      0.000 ...   632.999 secs...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# 442 events found
# Event IDs: [  1   2   4   6   8  10  12  16  32  64 128 132 140]
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1001 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1001 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1001 original time points ...
# 0 bad epochs dropped
# Opening raw data file E:/MSUPE/piansrann/meg/W010/230811/W010_b_2_run2_raw_tsss.fif...
#     Range : 75000 ... 721999 =     75.000 ...   721.999 secs
# Ready.
# Reading 0 ... 646999  =      0.000 ...   646.999 secs...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# 441 events found
# Event IDs: [  1   2   5   6   8  10  13  16  64 128 132 140]
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1001 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1001 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1001 original time points ...
# 0 bad epochs dropped
# Opening raw data file E:/MSUPE/piansrann/meg/W010/230811/W010_b_2_run3_raw_tsss.fif...
#     Range : 38000 ... 728999 =     38.000 ...   728.999 secs
# Ready.
# Reading 0 ... 690999  =      0.000 ...   690.999 secs...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# 442 events found
# Event IDs: [  1   2   5   6   8  10  13  16  64 128 132 140]
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1001 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1001 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1001 original time points ...
# 0 bad epochs dropped
# Opening raw data file E:/MSUPE/piansrann/meg/W011/230814/W011_c_2_run1_raw_tsss.fif...
#     Range : 320000 ... 924999 =    320.000 ...   924.999 secs
# Ready.
# Reading 0 ... 604999  =      0.000 ...   604.999 secs...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# 441 events found
# Event IDs: [  1   2   4   7   9  10  12  16  32  64 128 134 136]
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1001 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1001 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1001 original time points ...
# 0 bad epochs dropped
# Opening raw data file E:/MSUPE/piansrann/meg/W011/230814/W011_c_2_run2_raw_tsss.fif...
#     Range : 71000 ... 664999 =     71.000 ...   664.999 secs
# Ready.
# Reading 0 ... 593999  =      0.000 ...   593.999 secs...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# 450 events found
# Event IDs: [  1   2   4   7   9  10  12  16  64 128 134 136]
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1001 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1001 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1001 original time points ...
# 0 bad epochs dropped
# Opening raw data file E:/MSUPE/piansrann/meg/W011/230814/W011_c_2_run3_raw_tsss.fif...
#     Range : 81000 ... 705999 =     81.000 ...   705.999 secs
# Ready.
# Reading 0 ... 624999  =      0.000 ...   624.999 secs...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# 447 events found
# Event IDs: [  1   2   4   7   9  10  12  16  64 128 134 136]
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1001 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1001 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1001 original time points ...
# 0 bad epochs dropped
# Opening raw data file E:/MSUPE/piansrann/meg/W012/230816/W012_d_2_run1_raw_tsss.fif...
#     Range : 359000 ... 933999 =    359.000 ...   933.999 secs
# Ready.
# Reading 0 ... 574999  =      0.000 ...   574.999 secs...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# 442 events found
# Event IDs: [  1   2   4   7   8  11  12  16  32  64 128 134 138]
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1001 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1001 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1001 original time points ...
# 0 bad epochs dropped
# Opening raw data file E:/MSUPE/piansrann/meg/W012/230816/W012_d_2_run2_raw_tsss.fif...
#     Range : 92000 ... 747999 =     92.000 ...   747.999 secs
# Ready.
# Reading 0 ... 655999  =      0.000 ...   655.999 secs...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# 444 events found
# Event IDs: [  1   2   4   7   8  11  12  16  32  64 128 134 138]
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1001 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1001 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1001 original time points ...
# 0 bad epochs dropped
# Opening raw data file E:/MSUPE/piansrann/meg/W012/230816/W012_d_2_run3_raw_tsss.fif...
#     Range : 62000 ... 661999 =     62.000 ...   661.999 secs
# Ready.
# Reading 0 ... 599999  =      0.000 ...   599.999 secs...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# 442 events found
# Event IDs: [  1   2   4   7   8  11  12  16  32  64 128 134 138]
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1001 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1001 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1001 original time points ...
# 0 bad epochs dropped
# Opening raw data file E:/MSUPE/piansrann/meg/W013/230823/W013_a_2_run1_raw_tsss.fif...
#     Range : 559000 ... 1163999 =    559.000 ...  1163.999 secs
# Ready.
# Reading 0 ... 604999  =      0.000 ...   604.999 secs...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# 442 events found
# Event IDs: [  1   3   4   6   8  10  13  16  32  64 128 130 140]
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1001 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1001 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1001 original time points ...
# 0 bad epochs dropped
# Opening raw data file E:/MSUPE/piansrann/meg/W013/230823/W013_a_2_run2_raw_tsss.fif...
#     Range : 73000 ... 633999 =     73.000 ...   633.999 secs
# Ready.
# Reading 0 ... 560999  =      0.000 ...   560.999 secs...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# 443 events found
# Event IDs: [  1   3   4   6   8  10  12  13  16  64 128 130 140]
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1001 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1001 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1001 original time points ...
# 0 bad epochs dropped
# Opening raw data file E:/MSUPE/piansrann/meg/W013/230823/W013_a_2_run3_raw_tsss.fif...
#     Range : 110000 ... 661999 =    110.000 ...   661.999 secs
# Ready.
# Reading 0 ... 551999  =      0.000 ...   551.999 secs...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# 443 events found
# Event IDs: [  1   3   4   6   8  10  13  16  64 128 130 140]
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1001 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1001 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1001 original time points ...
# 0 bad epochs dropped
# Opening raw data file E:/MSUPE/piansrann/meg/W014/230831/W014_b_2_run1_raw_tsss.fif...
#     Range : 114000 ... 742999 =    114.000 ...   742.999 secs
# Ready.
# Reading 0 ... 628999  =      0.000 ...   628.999 secs...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# 441 events found
# Event IDs: [  1   2   5   6   8  10  13  16  32  64 128 132 140]
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1001 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1001 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1001 original time points ...
# 0 bad epochs dropped
# Opening raw data file E:/MSUPE/piansrann/meg/W014/230831/W014_b_2_run2_raw_tsss.fif...
#     Range : 144000 ... 715999 =    144.000 ...   715.999 secs
# Ready.
# Reading 0 ... 571999  =      0.000 ...   571.999 secs...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# 441 events found
# Event IDs: [  1   2   4   6   8  10  12  16  64 128 132 140]
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1001 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1001 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1001 original time points ...
# 0 bad epochs dropped
# Opening raw data file E:/MSUPE/piansrann/meg/W014/230831/W014_b_2_run3_raw_tsss.fif...
#     Range : 67000 ... 627999 =     67.000 ...   627.999 secs
# Ready.
# Reading 0 ... 560999  =      0.000 ...   560.999 secs...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# 440 events found
# Event IDs: [  1   2   5   6   8  10  13  16  64 128 132 140]
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1001 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1001 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1001 original time points ...
# 0 bad epochs dropped
# Opening raw data file E:/MSUPE/piansrann/meg/W015/230828/W015_c_2_run1_raw_tsss.fif...
#     Range : 200000 ... 828999 =    200.000 ...   828.999 secs
# Ready.
# Reading 0 ... 628999  =      0.000 ...   628.999 secs...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# 441 events found
# Event IDs: [  1   2   4   7   9  10  12  16  32  64 128 134 136]
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1001 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1001 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1001 original time points ...
# 0 bad epochs dropped
# Opening raw data file E:/MSUPE/piansrann/meg/W015/230828/W015_c_2_run2_raw_tsss.fif...
#     Range : 101000 ... 744999 =    101.000 ...   744.999 secs
# Ready.
# Reading 0 ... 643999  =      0.000 ...   643.999 secs...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# 441 events found
# Event IDs: [  1   2   4   7   9  10  12  16  64 128 134 136]
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1001 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1001 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1001 original time points ...
# 0 bad epochs dropped
# Opening raw data file E:/MSUPE/piansrann/meg/W015/230828/W015_c_2_run3_raw_tsss.fif...
#     Range : 41000 ... 710999 =     41.000 ...   710.999 secs
# Ready.
# Reading 0 ... 669999  =      0.000 ...   669.999 secs...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# 442 events found
# Event IDs: [  1   2   4   7   9  10  12  16  64 128 134 136]
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1001 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1001 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1001 original time points ...
# 0 bad epochs dropped

# %%
for subj in subjs:

    df = pd.DataFrame(columns=['subject', 'run',  'MISC001'])
    
    for i in range(2, 7):
        prot = subj[2]###
        subject = subj[0]
        path = f"E:/MSUPE/piansrann/meg/{subj[0]}/{subj[1]}/" ###
        run = i
        day = '1'
        file = f'{subject}_{prot[0]}_{day}_run{run}_raw_tsss.fif'  #####
        filename = path+file
        raw = mne.io.read_raw_fif(filename, preload=True)
        pivot_channels = mne.pick_types(raw.info, meg=False, eeg=False, stim=True, eog=False, misc=True)
        channels_of_interest = ['MISC001']
        channels_to_keep = [ch for ch in pivot_channels if raw.info['ch_names'][ch] in channels_of_interest]

        # Extract the data for the selected channels
        for_scr = raw.copy().pick_channels([raw.info['ch_names'][ch] for ch in channels_to_keep])
        #events
        events = mne.find_events(raw, min_duration=0, shortest_event = 0 )
        exclude=[1, 16, 32, 64, 128] #exclusion of event we do not need for further analysis ###############
        events = mne.pick_events(events, include=None, exclude=exclude, step=False)
        events_clean =[]
        tok = [130, 140, 132, 134, 136, 138]
        for i in range(0, len(events[:, 2])-3):
            if events[:, 2][i] == events[:, 2][i+2] or events[:, 2][i+2] in tok:
                events_clean.append(events[i])
        events_clean.append(events[len(events[:, 2])-3])
        events_clean = np.array(events_clean)
        if prot == b:
            for i in range(len(events_clean)):
                if events_clean[:, 2][i] == 12:
                    events_clean[:, 2][i] = 13
                if events_clean[:, 2][i] == 4:
                    events_clean[:, 2][i] = 5

        #epochs 
        epochs1 = mne.Epochs(for_scr, events_clean, picks=['MISC001'], event_id = prot[1], tmin=0, tmax=2, baseline=None, detrend = None, preload = True, reject_by_annotation = True,  on_missing='ignore')
        df1 = epochs1.to_data_frame()
        result1 = df1.groupby(["epoch", "condition"])['MISC001'].mean()
        result1 = result1.droplevel('epoch')
        result1 = result1.to_frame()
        result1.insert (0, 'run', run)
        result1.insert (0, 'subject', subject)
        result1.insert (0, 'time', '0-2')
        result1.insert (0, 'prot', prot[0])
        
        epochs2 = mne.Epochs(for_scr, events_clean, picks=['MISC001'], event_id = prot[1], tmin=6, tmax=8, baseline=None, detrend = None, preload = True, reject_by_annotation = True,  on_missing='ignore')
        df2 = epochs2.to_data_frame()
        result2 = df2.groupby(["epoch", "condition"])['MISC001'].mean()
        result2 = result2.to_frame()
        result2 = result2.droplevel('epoch')
        result2.insert (0, 'run', run)
        result2.insert (0, 'subject', subject)
        result2.insert (0, 'time', '6-8')
        result2.insert (0, 'prot', prot[0])



        test = pd.concat([result1, result2], axis=0)
        df = pd.concat([df, test], axis=0)
        df.to_csv(f'E:/MSUPE/piansrann/tables_veg/{subject}.csv')
# Out:
# Opening raw data file E:/MSUPE/piansrann/meg/W001/230628/W001_a_1_run2_raw_tsss.fif...
#     Range : 64000 ... 709999 =     64.000 ...   709.999 secs
# Ready.
# Reading 0 ... 645999  =      0.000 ...   645.999 secs...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# 440 events found
# Event IDs: [  1   3   4   6   8  10  13  16  32  64 128 130 140]
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 2001 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 2001 original time points ...
# 0 bad epochs dropped
# Opening raw data file E:/MSUPE/piansrann/meg/W001/230628/W001_a_1_run3_raw_tsss.fif...
#     Range : 151000 ... 762999 =    151.000 ...   762.999 secs
# Ready.
# Reading 0 ... 611999  =      0.000 ...   611.999 secs...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# 439 events found
# Event IDs: [  1   3   4   6   8  10  13  16  32  64 128 130 140]
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 2001 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 2001 original time points ...
# 1 bad epochs dropped
# Opening raw data file E:/MSUPE/piansrann/meg/W001/230628/W001_a_1_run4_raw_tsss.fif...
#     Range : 73000 ... 647999 =     73.000 ...   647.999 secs
# Ready.
# Reading 0 ... 574999  =      0.000 ...   574.999 secs...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# 440 events found
# Event IDs: [  1   3   4   6   8  10  13  16  64 128 130 140]
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 2001 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 2001 original time points ...
# 1 bad epochs dropped
# Opening raw data file E:/MSUPE/piansrann/meg/W001/230628/W001_a_1_run5_raw_tsss.fif...
#     Range : 42000 ... 613999 =     42.000 ...   613.999 secs
# Ready.
# Reading 0 ... 571999  =      0.000 ...   571.999 secs...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# 441 events found
# Event IDs: [  1   3   4   6   8  10  13  16  64 128 130 140]
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 2001 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 2001 original time points ...
# 1 bad epochs dropped
# Opening raw data file E:/MSUPE/piansrann/meg/W001/230628/W001_a_1_run6_raw_tsss.fif...
#     Range : 64000 ... 626999 =     64.000 ...   626.999 secs
# Ready.
# Reading 0 ... 562999  =      0.000 ...   562.999 secs...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# 448 events found
# Event IDs: [  1   3   4   6   8  10  13  16  64 128 130 140]
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 2001 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 2001 original time points ...
# 0 bad epochs dropped
# Opening raw data file E:/MSUPE/piansrann/meg/W002/230704/W002_b_1_run2_raw_tsss.fif...
#     Range : 57000 ... 715999 =     57.000 ...   715.999 secs
# Ready.
# Reading 0 ... 658999  =      0.000 ...   658.999 secs...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# 441 events found
# Event IDs: [  1   2   5   6   8  10  13  16  32  64 128 132 140]
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 2001 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 2001 original time points ...
# 1 bad epochs dropped
# Opening raw data file E:/MSUPE/piansrann/meg/W002/230704/W002_b_1_run3_raw_tsss.fif...
#     Range : 65000 ... 723999 =     65.000 ...   723.999 secs
# Ready.
# Reading 0 ... 658999  =      0.000 ...   658.999 secs...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# 441 events found
# Event IDs: [  1   2   4   6   8  10  12  16  32  64 128 132 140]
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 2001 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 2001 original time points ...
# 0 bad epochs dropped
# Opening raw data file E:/MSUPE/piansrann/meg/W002/230704/W002_b_1_run4_raw_tsss.fif...
#     Range : 23000 ... 636999 =     23.000 ...   636.999 secs
# Ready.
# Reading 0 ... 613999  =      0.000 ...   613.999 secs...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# 441 events found
# Event IDs: [  1   2   5   6   8  10  13  16  32  64 128 132 140]
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 2001 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 2001 original time points ...
# 0 bad epochs dropped
# Opening raw data file E:/MSUPE/piansrann/meg/W002/230704/W002_b_1_run5_raw_tsss.fif...
#     Range : 232000 ... 924999 =    232.000 ...   924.999 secs
# Ready.
# Reading 0 ... 692999  =      0.000 ...   692.999 secs...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# 441 events found
# Event IDs: [  1   2   5   6   8  10  13  16  32  64 128 132 140]
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 2001 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 2001 original time points ...
# 0 bad epochs dropped
# Opening raw data file E:/MSUPE/piansrann/meg/W002/230704/W002_b_1_run6_raw_tsss.fif...
#     Range : 33000 ... 636999 =     33.000 ...   636.999 secs
# Ready.
# Reading 0 ... 603999  =      0.000 ...   603.999 secs...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# 441 events found
# Event IDs: [  1   2   5   6   8  10  13  16  32  64 128 132 140]
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 2001 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 2001 original time points ...
# 0 bad epochs dropped
# Opening raw data file E:/MSUPE/piansrann/meg/W003/230710/W003_c_1_run2_raw_tsss.fif...
#     Range : 52000 ... 703999 =     52.000 ...   703.999 secs
# Ready.
# Reading 0 ... 651999  =      0.000 ...   651.999 secs...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# 441 events found
# Event IDs: [  1   2   4   7   9  10  12  16  32  64 128 134 136]
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 2001 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 2001 original time points ...
# 0 bad epochs dropped
# Opening raw data file E:/MSUPE/piansrann/meg/W003/230710/W003_c_1_run3_raw_tsss.fif...
#     Range : 90000 ... 759999 =     90.000 ...   759.999 secs
# Ready.
# Reading 0 ... 669999  =      0.000 ...   669.999 secs...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# 441 events found
# Event IDs: [  1   2   4   7   9  10  12  16  64 128 134 136]
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 2001 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 2001 original time points ...
# 1 bad epochs dropped
# Opening raw data file E:/MSUPE/piansrann/meg/W003/230710/W003_c_1_run4_raw_tsss.fif...
#     Range : 71000 ... 687999 =     71.000 ...   687.999 secs
# Ready.
# Reading 0 ... 616999  =      0.000 ...   616.999 secs...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# 441 events found
# Event IDs: [  1   2   4   7   9  10  12  16  64 128 134 136]
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 2001 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 2001 original time points ...
# 0 bad epochs dropped
# Opening raw data file E:/MSUPE/piansrann/meg/W003/230710/W003_c_1_run5_raw_tsss.fif...
#     Range : 49000 ... 618999 =     49.000 ...   618.999 secs
# Ready.
# Reading 0 ... 569999  =      0.000 ...   569.999 secs...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# 441 events found
# Event IDs: [  1   2   4   7   9  10  12  16  64 128 134 136]
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 2001 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 2001 original time points ...
# 0 bad epochs dropped
# Opening raw data file E:/MSUPE/piansrann/meg/W003/230710/W003_c_1_run6_raw_tsss.fif...
#     Range : 81000 ... 721999 =     81.000 ...   721.999 secs
# Ready.
# Reading 0 ... 640999  =      0.000 ...   640.999 secs...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# 441 events found
# Event IDs: [  1   2   4   7   9  10  12  16  64 128 134 136]
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 2001 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 2001 original time points ...
# 1 bad epochs dropped
# Opening raw data file E:/MSUPE/piansrann/meg/W004/230711/W004_d_1_run2_raw_tsss.fif...
#     Range : 85000 ... 690999 =     85.000 ...   690.999 secs
# Ready.
# Reading 0 ... 605999  =      0.000 ...   605.999 secs...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# 440 events found
# Event IDs: [  1   2   4   7   8  11  12  16  32  64 128 134 138]
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 2001 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 2001 original time points ...
# 0 bad epochs dropped
# Opening raw data file E:/MSUPE/piansrann/meg/W004/230711/W004_d_1_run3_raw_tsss.fif...
#     Range : 130000 ... 774999 =    130.000 ...   774.999 secs
# Ready.
# Reading 0 ... 644999  =      0.000 ...   644.999 secs...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# 440 events found
# Event IDs: [  1   2   4   7   8  11  12  16  64 128 134 138]
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 2001 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 2001 original time points ...
# 1 bad epochs dropped
# Opening raw data file E:/MSUPE/piansrann/meg/W004/230711/W004_d_1_run4_raw_tsss.fif...
#     Range : 24000 ... 639999 =     24.000 ...   639.999 secs
# Ready.
# Reading 0 ... 615999  =      0.000 ...   615.999 secs...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# 440 events found
# Event IDs: [  1   2   4   7   8  11  12  16  64 128 134 138]
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 2001 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 2001 original time points ...
# 0 bad epochs dropped
# Opening raw data file E:/MSUPE/piansrann/meg/W004/230711/W004_d_1_run5_raw_tsss.fif...
#     Range : 114000 ... 691999 =    114.000 ...   691.999 secs
# Ready.
# Reading 0 ... 577999  =      0.000 ...   577.999 secs...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# 440 events found
# Event IDs: [  1   2   4   7   8  11  12  16  64 128 134 138]
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 2001 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 2001 original time points ...
# 1 bad epochs dropped
# Opening raw data file E:/MSUPE/piansrann/meg/W004/230711/W004_d_1_run6_raw_tsss.fif...
#     Range : 103000 ... 711999 =    103.000 ...   711.999 secs
# Ready.
# Reading 0 ... 608999  =      0.000 ...   608.999 secs...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# 440 events found
# Event IDs: [  1   2   4   7   8  11  12  16  64 128 134 138]
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 2001 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 2001 original time points ...
# 0 bad epochs dropped
# Opening raw data file E:/MSUPE/piansrann/meg/W005/230714/W005_a_1_run2_raw_tsss.fif...
#     Range : 172000 ... 754999 =    172.000 ...   754.999 secs
# Ready.
# Reading 0 ... 582999  =      0.000 ...   582.999 secs...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# 441 events found
# Event IDs: [  1   3   4   6   8  10  13  16  64 128 130 140]
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 2001 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 2001 original time points ...
# 1 bad epochs dropped
# Opening raw data file E:/MSUPE/piansrann/meg/W005/230714/W005_a_1_run3_raw_tsss.fif...
#     Range : 35000 ... 627999 =     35.000 ...   627.999 secs
# Ready.
# Reading 0 ... 592999  =      0.000 ...   592.999 secs...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# 440 events found
# Event IDs: [  1   3   4   6   8  10  13  16  64 128 130 140]
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 2001 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 2001 original time points ...
# 0 bad epochs dropped
# Opening raw data file E:/MSUPE/piansrann/meg/W005/230714/W005_a_1_run4_raw_tsss.fif...
#     Range : 50000 ... 630999 =     50.000 ...   630.999 secs
# Ready.
# Reading 0 ... 580999  =      0.000 ...   580.999 secs...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# 440 events found
# Event IDs: [  1   3   4   6   8  10  13  16  64 128 130 140]
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 2001 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 2001 original time points ...
# 0 bad epochs dropped
# Opening raw data file E:/MSUPE/piansrann/meg/W005/230714/W005_a_1_run5_raw_tsss.fif...
#     Range : 37000 ... 674999 =     37.000 ...   674.999 secs
# Ready.
# Reading 0 ... 637999  =      0.000 ...   637.999 secs...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# 440 events found
# Event IDs: [  1   3   4   6   8  10  13  16  64 128 130 140]
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 2001 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 2001 original time points ...
# 1 bad epochs dropped
# Opening raw data file E:/MSUPE/piansrann/meg/W005/230714/W005_a_1_run6_raw_tsss.fif...
#     Range : 100000 ... 696999 =    100.000 ...   696.999 secs
# Ready.
# Reading 0 ... 596999  =      0.000 ...   596.999 secs...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# 440 events found
# Event IDs: [  1   3   4   6   8  10  13  16  64 128 130 140]
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 2001 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 2001 original time points ...
# 0 bad epochs dropped
# Opening raw data file E:/MSUPE/piansrann/meg/W006/230718/W006_b_1_run2_raw_tsss.fif...
#     Range : 186000 ... 838999 =    186.000 ...   838.999 secs
# Ready.
# Reading 0 ... 652999  =      0.000 ...   652.999 secs...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# 441 events found
# Event IDs: [  1   2   5   6   8  10  13  16  32  64 128 132 140]
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 2001 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 2001 original time points ...
# 1 bad epochs dropped
# Opening raw data file E:/MSUPE/piansrann/meg/W006/230718/W006_b_1_run3_raw_tsss.fif...
#     Range : 215000 ... 833999 =    215.000 ...   833.999 secs
# Ready.
# Reading 0 ... 618999  =      0.000 ...   618.999 secs...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# 441 events found
# Event IDs: [  1   2   4   6   8  10  12  16  32  64 128 132 140]
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 2001 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 2001 original time points ...
# 1 bad epochs dropped
# Opening raw data file E:/MSUPE/piansrann/meg/W006/230718/W006_b_1_run4_raw_tsss.fif...
#     Range : 127000 ... 750999 =    127.000 ...   750.999 secs
# Ready.
# Reading 0 ... 623999  =      0.000 ...   623.999 secs...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# 440 events found
# Event IDs: [  1   2   5   6   8  10  13  16  64 128 132 140]
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 2001 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 2001 original time points ...
# 0 bad epochs dropped
# Opening raw data file E:/MSUPE/piansrann/meg/W006/230718/W006_b_1_run5_raw_tsss.fif...
#     Range : 70000 ... 687999 =     70.000 ...   687.999 secs
# Ready.
# Reading 0 ... 617999  =      0.000 ...   617.999 secs...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# 441 events found
# Event IDs: [  1   2   5   6   8  10  13  16  64 128 132 140]
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 2001 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 2001 original time points ...
# 1 bad epochs dropped
# Opening raw data file E:/MSUPE/piansrann/meg/W006/230718/W006_b_1_run6_raw_tsss.fif...
#     Range : 58000 ... 640999 =     58.000 ...   640.999 secs
# Ready.
# Reading 0 ... 582999  =      0.000 ...   582.999 secs...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# 440 events found
# Event IDs: [  1   2   5   6   8  10  13  16  64 128 132 140]
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 2001 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 2001 original time points ...
# 0 bad epochs dropped
# Opening raw data file E:/MSUPE/piansrann/meg/W007/230722/W007_c_1_run2_raw_tsss.fif...
#     Range : 160000 ... 785999 =    160.000 ...   785.999 secs
# Ready.
# Reading 0 ... 625999  =      0.000 ...   625.999 secs...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# 440 events found
# Event IDs: [  1   2   4   7   9  10  12  16  32  64 128 134 136]
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 2001 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 2001 original time points ...
# 1 bad epochs dropped
# Opening raw data file E:/MSUPE/piansrann/meg/W007/230722/W007_c_1_run3_raw_tsss.fif...
#     Range : 78000 ... 699999 =     78.000 ...   699.999 secs
# Ready.
# Reading 0 ... 621999  =      0.000 ...   621.999 secs...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# 439 events found
# Event IDs: [  1   2   4   7   9  10  12  16  32  64 128 134 136]
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 2001 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 2001 original time points ...
# 1 bad epochs dropped
# Opening raw data file E:/MSUPE/piansrann/meg/W007/230722/W007_c_1_run4_raw_tsss.fif...
#     Range : 23000 ... 673999 =     23.000 ...   673.999 secs
# Ready.
# Reading 0 ... 650999  =      0.000 ...   650.999 secs...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# 440 events found
# Event IDs: [  1   2   4   7   9  10  12  16  64 128 134 136]
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 2001 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 2001 original time points ...
# 0 bad epochs dropped
# Opening raw data file E:/MSUPE/piansrann/meg/W007/230722/W007_c_1_run5_raw_tsss.fif...
#     Range : 25000 ... 662999 =     25.000 ...   662.999 secs
# Ready.
# Reading 0 ... 637999  =      0.000 ...   637.999 secs...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# 440 events found
# Event IDs: [  1   2   4   7   9  10  12  16  64 128 134 136]
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 2001 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 2001 original time points ...
# 1 bad epochs dropped
# Opening raw data file E:/MSUPE/piansrann/meg/W007/230722/W007_c_1_run6_raw_tsss.fif...
#     Range : 42000 ... 688999 =     42.000 ...   688.999 secs
# Ready.
# Reading 0 ... 646999  =      0.000 ...   646.999 secs...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# 440 events found
# Event IDs: [  1   2   4   7   9  10  12  16  64 128 134 136]
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 2001 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 2001 original time points ...
# 0 bad epochs dropped
# Opening raw data file E:/MSUPE/piansrann/meg/W008/230724/W008_d_1_run2_raw_tsss.fif...
#     Range : 52000 ... 702999 =     52.000 ...   702.999 secs
# Ready.
# Reading 0 ... 650999  =      0.000 ...   650.999 secs...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# 440 events found
# Event IDs: [  1   2   4   7   8  11  12  16  32  64 128 134 138]
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 2001 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 2001 original time points ...
# 1 bad epochs dropped
# Opening raw data file E:/MSUPE/piansrann/meg/W008/230724/W008_d_1_run3_raw_tsss.fif...
#     Range : 42000 ... 670999 =     42.000 ...   670.999 secs
# Ready.
# Reading 0 ... 628999  =      0.000 ...   628.999 secs...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# 440 events found
# Event IDs: [  1   2   4   7   8  11  12  16  32  64 128 134 138]
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 2001 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 2001 original time points ...
# 0 bad epochs dropped
# Opening raw data file E:/MSUPE/piansrann/meg/W008/230724/W008_d_1_run4_raw_tsss.fif...
#     Range : 48000 ... 672999 =     48.000 ...   672.999 secs
# Ready.
# Reading 0 ... 624999  =      0.000 ...   624.999 secs...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# 440 events found
# Event IDs: [  1   2   4   7   8  11  12  16  64 128 134 138]
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 2001 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 2001 original time points ...
# 0 bad epochs dropped
# Opening raw data file E:/MSUPE/piansrann/meg/W008/230724/W008_d_1_run5_raw_tsss.fif...
#     Range : 28000 ... 660999 =     28.000 ...   660.999 secs
# Ready.
# Reading 0 ... 632999  =      0.000 ...   632.999 secs...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# 442 events found
# Event IDs: [  1   2   4   7   8  11  12  16  32  64 128 134 138]
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 2001 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 2001 original time points ...
# 0 bad epochs dropped
# Opening raw data file E:/MSUPE/piansrann/meg/W008/230724/W008_d_1_run6_raw_tsss.fif...
#     Range : 26000 ... 619999 =     26.000 ...   619.999 secs
# Ready.
# Reading 0 ... 593999  =      0.000 ...   593.999 secs...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# 440 events found
# Event IDs: [  1   2   4   7   8  11  12  16  64 128 134 138]
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 2001 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 2001 original time points ...
# 0 bad epochs dropped
# Opening raw data file E:/MSUPE/piansrann/meg/W009/230804/W009_a_1_run2_raw_tsss.fif...
#     Range : 32000 ... 697999 =     32.000 ...   697.999 secs
# Ready.
# Reading 0 ... 665999  =      0.000 ...   665.999 secs...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# 440 events found
# Event IDs: [  1   3   4   6   8  10  13  16  32  64 128 130 140]
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 2001 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 2001 original time points ...
# 0 bad epochs dropped
# Opening raw data file E:/MSUPE/piansrann/meg/W009/230804/W009_a_1_run3_raw_tsss.fif...
#     Range : 44000 ... 701999 =     44.000 ...   701.999 secs
# Ready.
# Reading 0 ... 657999  =      0.000 ...   657.999 secs...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# 440 events found
# Event IDs: [  1   3   4   6   8  10  13  16  32  64 128 130 140]
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 2001 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 2001 original time points ...
# 0 bad epochs dropped
# Opening raw data file E:/MSUPE/piansrann/meg/W009/230804/W009_a_1_run4_raw_tsss.fif...
#     Range : 55000 ... 687999 =     55.000 ...   687.999 secs
# Ready.
# Reading 0 ... 632999  =      0.000 ...   632.999 secs...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# 426 events found
# Event IDs: [  1   3   4   6   8  10  13  16  32  64 128 130 140]
# Not setting metadata
# 58 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 58 events and 2001 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 58 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 58 events and 2001 original time points ...
# 0 bad epochs dropped
# Opening raw data file E:/MSUPE/piansrann/meg/W009/230804/W009_a_1_run5_raw_tsss.fif...
#     Range : 53000 ... 655999 =     53.000 ...   655.999 secs
# Ready.
# Reading 0 ... 602999  =      0.000 ...   602.999 secs...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# 440 events found
# Event IDs: [  1   3   4   6   8  10  13  16  32  64 128 130 140]
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 2001 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 2001 original time points ...
# 0 bad epochs dropped
# Opening raw data file E:/MSUPE/piansrann/meg/W009/230804/W009_a_1_run6_raw_tsss.fif...
#     Range : 46000 ... 623999 =     46.000 ...   623.999 secs
# Ready.
# Reading 0 ... 577999  =      0.000 ...   577.999 secs...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# 440 events found
# Event IDs: [  1   3   4   6   8  10  13  16  64 128 130 140]
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 2001 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 2001 original time points ...
# 0 bad epochs dropped
# Opening raw data file E:/MSUPE/piansrann/meg/W010/230804/W010_b_1_run2_raw_tsss.fif...
#     Range : 200000 ... 854999 =    200.000 ...   854.999 secs
# Ready.
# Reading 0 ... 654999  =      0.000 ...   654.999 secs...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# 441 events found
# Event IDs: [  1   2   5   6   8  10  13  16  32  64 128 132 140]
# Not setting metadata
# 62 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 62 events and 2001 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 62 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 62 events and 2001 original time points ...
# 1 bad epochs dropped
# Opening raw data file E:/MSUPE/piansrann/meg/W010/230804/W010_b_1_run3_raw_tsss.fif...
#     Range : 203000 ... 771999 =    203.000 ...   771.999 secs
# Ready.
# Reading 0 ... 568999  =      0.000 ...   568.999 secs...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# 441 events found
# Event IDs: [  1   2   4   6   8  10  12  16  64 128 132 140]
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 2001 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 2001 original time points ...
# 0 bad epochs dropped
# Opening raw data file E:/MSUPE/piansrann/meg/W010/230804/W010_b_1_run4_raw_tsss.fif...
#     Range : 142000 ... 778999 =    142.000 ...   778.999 secs
# Ready.
# Reading 0 ... 636999  =      0.000 ...   636.999 secs...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# 441 events found
# Event IDs: [  1   2   5   6   8  10  13  16  64 128 132 140]
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 2001 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 2001 original time points ...
# 0 bad epochs dropped
# Opening raw data file E:/MSUPE/piansrann/meg/W010/230804/W010_b_1_run5_raw_tsss.fif...
#     Range : 101000 ... 769999 =    101.000 ...   769.999 secs
# Ready.
# Reading 0 ... 668999  =      0.000 ...   668.999 secs...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# 441 events found
# Event IDs: [  1   2   5   6   8  10  13  16  64 128 132 140]
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 2001 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 2001 original time points ...
# 0 bad epochs dropped
# Opening raw data file E:/MSUPE/piansrann/meg/W010/230804/W010_b_1_run6_raw_tsss.fif...
#     Range : 83000 ... 744999 =     83.000 ...   744.999 secs
# Ready.
# Reading 0 ... 661999  =      0.000 ...   661.999 secs...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# 441 events found
# Event IDs: [  1   2   5   6   8  10  13  16  64 128 132 140]
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 2001 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 2001 original time points ...
# 0 bad epochs dropped
# Opening raw data file E:/MSUPE/piansrann/meg/W011/230807/W011_c_1_run2_raw_tsss.fif...
#     Range : 62000 ... 699999 =     62.000 ...   699.999 secs
# Ready.
# Reading 0 ... 637999  =      0.000 ...   637.999 secs...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# 446 events found
# Event IDs: [  1   2   4   7   9  10  12  16  32  64 128 134 136]
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 2001 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 2001 original time points ...
# 1 bad epochs dropped
# Opening raw data file E:/MSUPE/piansrann/meg/W011/230807/W011_c_1_run3_raw_tsss.fif...
#     Range : 143000 ... 776999 =    143.000 ...   776.999 secs
# Ready.
# Reading 0 ... 633999  =      0.000 ...   633.999 secs...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# 443 events found
# Event IDs: [  1   2   4   7   9  10  12  16  64 128 134 136]
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 2001 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 2001 original time points ...
# 0 bad epochs dropped
# Opening raw data file E:/MSUPE/piansrann/meg/W011/230807/W011_c_1_run4_raw_tsss.fif...
#     Range : 44000 ... 689999 =     44.000 ...   689.999 secs
# Ready.
# Reading 0 ... 645999  =      0.000 ...   645.999 secs...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# 445 events found
# Event IDs: [  1   2   4   7   9  10  12  16  64 128 134 136]
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 2001 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 2001 original time points ...
# 1 bad epochs dropped
# Opening raw data file E:/MSUPE/piansrann/meg/W011/230807/W011_c_1_run5_raw_tsss.fif...
#     Range : 73000 ... 668999 =     73.000 ...   668.999 secs
# Ready.
# Reading 0 ... 595999  =      0.000 ...   595.999 secs...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# 448 events found
# Event IDs: [  1   2   4   6   7   9  10  12  16  64 128 134 136]
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 2001 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 2001 original time points ...
# 0 bad epochs dropped
# Opening raw data file E:/MSUPE/piansrann/meg/W011/230807/W011_c_1_run6_raw_tsss.fif...
#     Range : 51000 ... 648999 =     51.000 ...   648.999 secs
# Ready.
# Reading 0 ... 597999  =      0.000 ...   597.999 secs...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# 445 events found
# Event IDs: [  1   2   4   7   9  10  12  16  64 128 134 136]
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 2001 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 2001 original time points ...
# 0 bad epochs dropped
# Opening raw data file E:/MSUPE/piansrann/meg/W012/230809/W012_d_1_run2_raw_tsss.fif...
#     Range : 79000 ... 688999 =     79.000 ...   688.999 secs
# Ready.
# Reading 0 ... 609999  =      0.000 ...   609.999 secs...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# 442 events found
# Event IDs: [  1   2   4   7   8  11  12  16  32  64 128 134 138]
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 2001 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 2001 original time points ...
# 0 bad epochs dropped
# Opening raw data file E:/MSUPE/piansrann/meg/W012/230809/W012_d_1_run3_raw_tsss.fif...
#     Range : 56000 ... 615999 =     56.000 ...   615.999 secs
# Ready.
# Reading 0 ... 559999  =      0.000 ...   559.999 secs...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# 442 events found
# Event IDs: [  1   2   4   7   8  11  12  16  32  64 128 134 138]
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 2001 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 2001 original time points ...
# 0 bad epochs dropped
# Opening raw data file E:/MSUPE/piansrann/meg/W012/230809/W012_d_1_run4_raw_tsss.fif...
#     Range : 57000 ... 674999 =     57.000 ...   674.999 secs
# Ready.
# Reading 0 ... 617999  =      0.000 ...   617.999 secs...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# 442 events found
# Event IDs: [  1   2   4   7   8  11  12  16  32  64 128 134 138]
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 2001 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 2001 original time points ...
# 1 bad epochs dropped
# Opening raw data file E:/MSUPE/piansrann/meg/W012/230809/W012_d_1_run5_raw_tsss.fif...
#     Range : 31000 ... 666999 =     31.000 ...   666.999 secs
# Ready.
# Reading 0 ... 635999  =      0.000 ...   635.999 secs...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# 442 events found
# Event IDs: [  1   2   4   7   8  11  12  16  32  64 128 134 138]
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 2001 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 2001 original time points ...
# 0 bad epochs dropped
# Opening raw data file E:/MSUPE/piansrann/meg/W012/230809/W012_d_1_run6_raw_tsss.fif...
#     Range : 68000 ... 630999 =     68.000 ...   630.999 secs
# Ready.
# Reading 0 ... 562999  =      0.000 ...   562.999 secs...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# 442 events found
# Event IDs: [  1   2   4   7   8  11  12  16  32  64 128 134 138]
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 2001 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 2001 original time points ...
# 0 bad epochs dropped
# Opening raw data file E:/MSUPE/piansrann/meg/W013/230816/W013_a_1_run2_raw_tsss.fif...
#     Range : 76000 ... 691999 =     76.000 ...   691.999 secs
# Ready.
# Reading 0 ... 615999  =      0.000 ...   615.999 secs...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# 443 events found
# Event IDs: [  1   3   4   6   8  10  13  16  32  64 128 130 140]
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 2001 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 2001 original time points ...
# 1 bad epochs dropped
# Opening raw data file E:/MSUPE/piansrann/meg/W013/230816/W013_a_1_run3_raw_tsss.fif...
#     Range : 23000 ... 609999 =     23.000 ...   609.999 secs
# Ready.
# Reading 0 ... 586999  =      0.000 ...   586.999 secs...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# 442 events found
# Event IDs: [  1   3   4   6   8  10  13  16  64 128 130 140]
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 2001 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 2001 original time points ...
# 1 bad epochs dropped
# Opening raw data file E:/MSUPE/piansrann/meg/W013/230816/W013_a_1_run4_raw_tsss.fif...
#     Range : 54000 ... 713999 =     54.000 ...   713.999 secs
# Ready.
# Reading 0 ... 659999  =      0.000 ...   659.999 secs...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# 444 events found
# Event IDs: [  1   3   4   6   8  10  13  16  64 128 130 140]
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 2001 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 2001 original time points ...
# 0 bad epochs dropped
# Opening raw data file E:/MSUPE/piansrann/meg/W013/230816/W013_a_1_run5_raw_tsss.fif...
#     Range : 41000 ... 694999 =     41.000 ...   694.999 secs
# Ready.
# Reading 0 ... 653999  =      0.000 ...   653.999 secs...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# 442 events found
# Event IDs: [  1   3   4   6   8  10  13  16  64 128 130 140]
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 2001 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 2001 original time points ...
# 0 bad epochs dropped
# Opening raw data file E:/MSUPE/piansrann/meg/W013/230816/W013_a_1_run6_raw_tsss.fif...
#     Range : 32000 ... 681999 =     32.000 ...   681.999 secs
# Ready.
# Reading 0 ... 649999  =      0.000 ...   649.999 secs...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# 442 events found
# Event IDs: [  1   3   4   6   8  10  13  16  64 128 130 140]
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 2001 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 2001 original time points ...
# 1 bad epochs dropped
# Opening raw data file E:/MSUPE/piansrann/meg/W014/230821/W014_b_1_run2_raw_tsss.fif...
#     Range : 52000 ... 615999 =     52.000 ...   615.999 secs
# Ready.
# Reading 0 ... 563999  =      0.000 ...   563.999 secs...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# 441 events found
# Event IDs: [  1   2   5   6   8  10  13  16  64 128 132 140]
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 2001 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 2001 original time points ...
# 0 bad epochs dropped
# Opening raw data file E:/MSUPE/piansrann/meg/W014/230821/W014_b_1_run3_raw_tsss.fif...
#     Range : 72000 ... 696999 =     72.000 ...   696.999 secs
# Ready.
# Reading 0 ... 624999  =      0.000 ...   624.999 secs...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# 440 events found
# Event IDs: [  1   2   4   6   8  10  12  16  64 128 132 140]
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 2001 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 2001 original time points ...
# 1 bad epochs dropped
# Opening raw data file E:/MSUPE/piansrann/meg/W014/230821/W014_b_1_run4_raw_tsss.fif...
#     Range : 57000 ... 690999 =     57.000 ...   690.999 secs
# Ready.
# Reading 0 ... 633999  =      0.000 ...   633.999 secs...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# 441 events found
# Event IDs: [  1   2   5   6   8  10  13  16  64 128 132 140]
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 2001 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 2001 original time points ...
# 0 bad epochs dropped
# Opening raw data file E:/MSUPE/piansrann/meg/W014/230821/W014_b_1_run5_raw_tsss.fif...
#     Range : 79000 ... 764999 =     79.000 ...   764.999 secs
# Ready.
# Reading 0 ... 685999  =      0.000 ...   685.999 secs...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# 440 events found
# Event IDs: [  1   2   4   5   6   8  10  13  16  64 128 132 140]
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 2001 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 2001 original time points ...
# 0 bad epochs dropped
# Opening raw data file E:/MSUPE/piansrann/meg/W014/230821/W014_b_1_run6_raw_tsss.fif...
#     Range : 117000 ... 674999 =    117.000 ...   674.999 secs
# Ready.
# Reading 0 ... 557999  =      0.000 ...   557.999 secs...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# 439 events found
# Event IDs: [  1   2   5   6   8  10  13  16  64 128 132 140]
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 2001 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 2001 original time points ...
# 0 bad epochs dropped
# Opening raw data file E:/MSUPE/piansrann/meg/W015/230821/W015_c_1_run2_raw_tsss.fif...
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[132], line 13
#      11 file = f'{subject}_{prot[0]}_{day}_run{run}_raw_tsss.fif'  #####
#      12 filename = path+file
# ---> 13 raw = mne.io.read_raw_fif(filename, preload=True)
#      14 pivot_channels = mne.pick_types(raw.info, meg=False, eeg=False, stim=True, eog=False, misc=True)
#      15 channels_of_interest = ['MISC001']
#
# File C:\Users\Anaconda\envs\mne\lib\site-packages\mne\io\fiff\raw.py:540, in read_raw_fif(fname, allow_maxshield, preload, on_split_missing, verbose)
#     499 @fill_doc
#     500 def read_raw_fif(
#     501     fname, allow_maxshield=False, preload=False, on_split_missing="raise", verbose=None
#     502 ):
#     503     """Reader function for Raw FIF data.
#     504
#     505     Parameters
#    (...)
#     538     are updated accordingly.
#     539     """
# --> 540     return Raw(
#     541         fname=fname,
#     542         allow_maxshield=allow_maxshield,
#     543         preload=preload,
#     544         verbose=verbose,
#     545         on_split_missing=on_split_missing,
#     546     )
#
# File <decorator-gen-271>:12, in __init__(self, fname, allow_maxshield, preload, on_split_missing, verbose)
#
# File C:\Users\Anaconda\envs\mne\lib\site-packages\mne\io\fiff\raw.py:93, in Raw.__init__(self, fname, allow_maxshield, preload, on_split_missing, verbose)
#      91 next_fname = fname
#      92 while next_fname is not None:
# ---> 93     raw, next_fname, buffer_size_sec = self._read_raw_file(
#      94         next_fname, allow_maxshield, preload, do_check_ext
#      95     )
#      96     do_check_ext = False
#      97     raws.append(raw)
#
# File <decorator-gen-272>:12, in _read_raw_file(self, fname, allow_maxshield, preload, do_check_ext, verbose)
#
# File C:\Users\Anaconda\envs\mne\lib\site-packages\mne\io\fiff\raw.py:175, in Raw._read_raw_file(self, fname, allow_maxshield, preload, do_check_ext, verbose)
#     173     check_fname(fname, "raw", endings)
#     174 # filename
# --> 175 fname = str(_check_fname(fname, "read", True, "fname"))
#     176 ext = os.path.splitext(fname)[1].lower()
#     177 whole_file = preload if ".gz" in ext else False
#
# File <decorator-gen-0>:12, in _check_fname(fname, overwrite, must_exist, name, need_dir, verbose)
#
# File C:\Users\Anaconda\envs\mne\lib\site-packages\mne\utils\check.py:250, in _check_fname(fname, overwrite, must_exist, name, need_dir, verbose)
#     248             raise PermissionError(f"{name} does not have read permissions: {fname}")
#     249 elif must_exist:
# --> 250     raise FileNotFoundError(f"{name} does not exist: {fname}")
#     252 return fname
#
# FileNotFoundError: fname does not exist: E:\MSUPE\piansrann\meg\W015\230821\W015_c_1_run2_raw_tsss.fif

# %%
epochs1

# %%
df

# %%
#all frames to one

# %%
os.chdir("E:/MSUPE/piansrann/tables_veg/")
file_list = os.listdir('E:/MSUPE/piansrann/tables_veg/')
print(file_list)
tables = [ pd.read_csv(f)
    for f in file_list]
print(tables)
# Out:
# ['W001.csv', 'W002.csv', 'W003.csv', 'W004.csv', 'W005.csv', 'W006.csv', 'W007.csv', 'W008.csv', 'W009.csv', 'W010.csv', 'W011.csv', 'W012.csv', 'W013.csv', 'W014.csv']
# [             Unnamed: 0 subject  run   MISC001 prot time
# 0     Compl_Elm_Minus_A    W001    2  0.182061    a  0-2
# 1    Sound_Elm_Plus__AR    W001    2  0.171893    a  0-2
# 2     Compl_Elm_Minus_A    W001    2  0.165625    a  0-2
# 3    Compl_Cfg_Plus__AR    W001    2  0.158446    a  0-2
# 4     Pictu_Elm_Minus_A    W001    2  0.171503    a  0-2
# ..                  ...     ...  ...       ...  ...  ...
# 592   Sound_Cfg_Minus_A    W001    6  0.105778    a  6-8
# 593   Pictu_Elm_Minus_A    W001    6  0.105151    a  6-8
# 594   Pictu_Cfg_Minus_A    W001    6  0.102567    a  6-8
# 595   Pictu_Elm_Minus_A    W001    6  0.113496    a  6-8
# 596   Sound_Cfg_Minus_A    W001    6  0.127795    a  6-8
#
# [597 rows x 6 columns],              Unnamed: 0 subject  run   MISC001 prot time
# 0    Compl_Cfg_Plus__AR    W002    2  0.060699    b  0-2
# 1    Pictu_Elm_Plus__AR    W002    2  0.089671    b  0-2
# 2     Sound_Elm_Minus_A    W002    2  0.096477    b  0-2
# 3    Pictu_Elm_Plus__AR    W002    2  0.096074    b  0-2
# 4    Compl_Cfg_Plus__AR    W002    2  0.109572    b  0-2
# ..                  ...     ...  ...       ...  ...  ...
# 594  Compl_Cfg_Plus__AR    W002    6  0.046630    b  6-8
# 595   Sound_Cfg_Minus_A    W002    6  0.047626    b  6-8
# 596   Compl_Elm_Minus_A    W002    6  0.046629    b  6-8
# 597   Sound_Elm_Minus_A    W002    6  0.045792    b  6-8
# 598  Pictu_Elm_Plus__AR    W002    6  0.047321    b  6-8
#
# [599 rows x 6 columns],              Unnamed: 0 subject  run   MISC001 prot time
# 0     Compl_Elm_Minus_A    W003    2  0.161582    c  0-2
# 1     Sound_Cfg_Minus_A    W003    2  0.181211    c  0-2
# 2     Pictu_Elm_Minus_A    W003    2  0.183720    c  0-2
# 3    Compl_Cfg_Plus__AR    W003    2  0.196640    c  0-2
# 4    Sound_Elm_Plus__AR    W003    2  0.230497    c  0-2
# ..                  ...     ...  ...       ...  ...  ...
# 593   Pictu_Elm_Minus_A    W003    6  0.227459    c  6-8
# 594   Compl_Elm_Minus_A    W003    6  0.207256    c  6-8
# 595  Sound_Elm_Plus__AR    W003    6  0.230575    c  6-8
# 596  Compl_Cfg_Plus__AR    W003    6  0.219272    c  6-8
# 597   Sound_Cfg_Minus_A    W003    6  0.205501    c  6-8
#
# [598 rows x 6 columns],              Unnamed: 0 subject  run   MISC001 prot time
# 0    Compl_Cfg_Plus__AR    W004    2  0.145297    d  0-2
# 1    Pictu_Elm_Plus__AR    W004    2  0.167050    d  0-2
# 2     Sound_Cfg_Minus_A    W004    2  0.179545    d  0-2
# 3     Sound_Elm_Minus_A    W004    2  0.175322    d  0-2
# 4     Sound_Cfg_Minus_A    W004    2  0.172106    d  0-2
# ..                  ...     ...  ...       ...  ...  ...
# 593   Compl_Elm_Minus_A    W004    6  0.138002    d  6-8
# 594  Compl_Cfg_Plus__AR    W004    6  0.137466    d  6-8
# 595   Pictu_Cfg_Minus_A    W004    6  0.137570    d  6-8
# 596   Sound_Elm_Minus_A    W004    6  0.136052    d  6-8
# 597   Compl_Elm_Minus_A    W004    6  0.134656    d  6-8
#
# [598 rows x 6 columns],              Unnamed: 0 subject  run   MISC001 prot time
# 0     Compl_Elm_Minus_A    W005    2  0.076793    a  0-2
# 1     Sound_Cfg_Minus_A    W005    2  0.111985    a  0-2
# 2    Compl_Cfg_Plus__AR    W005    2  0.133572    a  0-2
# 3     Pictu_Elm_Minus_A    W005    2  0.179619    a  0-2
# 4     Compl_Elm_Minus_A    W005    2  0.143948    a  0-2
# ..                  ...     ...  ...       ...  ...  ...
# 593   Pictu_Cfg_Minus_A    W005    6  0.188305    a  6-8
# 594   Pictu_Elm_Minus_A    W005    6  0.181063    a  6-8
# 595   Sound_Cfg_Minus_A    W005    6  0.172223    a  6-8
# 596  Sound_Elm_Plus__AR    W005    6  0.202655    a  6-8
# 597   Compl_Elm_Minus_A    W005    6  0.188059    a  6-8
#
# [598 rows x 6 columns],              Unnamed: 0 subject  run   MISC001 prot time
# 0    Pictu_Elm_Plus__AR    W006    2  0.212294    b  0-2
# 1     Compl_Elm_Minus_A    W006    2  0.257570    b  0-2
# 2     Pictu_Cfg_Minus_A    W006    2  0.203394    b  0-2
# 3     Sound_Elm_Minus_A    W006    2  0.191276    b  0-2
# 4    Compl_Cfg_Plus__AR    W006    2  0.221938    b  0-2
# ..                  ...     ...  ...       ...  ...  ...
# 592   Compl_Elm_Minus_A    W006    6  0.108556    b  6-8
# 593   Sound_Elm_Minus_A    W006    6  0.129532    b  6-8
# 594   Sound_Cfg_Minus_A    W006    6  0.115428    b  6-8
# 595  Compl_Cfg_Plus__AR    W006    6  0.118489    b  6-8
# 596  Pictu_Elm_Plus__AR    W006    6  0.126736    b  6-8
#
# [597 rows x 6 columns],              Unnamed: 0 subject  run   MISC001 prot time
# 0     Pictu_Cfg_Minus_A    W007    2  0.074238    c  0-2
# 1     Sound_Cfg_Minus_A    W007    2  0.075062    c  0-2
# 2     Compl_Elm_Minus_A    W007    2  0.088628    c  0-2
# 3     Pictu_Elm_Minus_A    W007    2  0.084612    c  0-2
# 4    Sound_Elm_Plus__AR    W007    2  0.087741    c  0-2
# ..                  ...     ...  ...       ...  ...  ...
# 592  Compl_Cfg_Plus__AR    W007    6  0.036423    c  6-8
# 593   Compl_Elm_Minus_A    W007    6  0.035680    c  6-8
# 594   Pictu_Cfg_Minus_A    W007    6  0.035186    c  6-8
# 595   Sound_Cfg_Minus_A    W007    6  0.034515    c  6-8
# 596  Sound_Elm_Plus__AR    W007    6  0.034523    c  6-8
#
# [597 rows x 6 columns],              Unnamed: 0 subject  run   MISC001 prot time
# 0     Sound_Cfg_Minus_A    W008    2  0.086186    d  0-2
# 1    Compl_Cfg_Plus__AR    W008    2  0.092136    d  0-2
# 2    Pictu_Elm_Plus__AR    W008    2  0.109821    d  0-2
# 3    Compl_Cfg_Plus__AR    W008    2  0.117200    d  0-2
# 4     Compl_Elm_Minus_A    W008    2  0.119466    d  0-2
# ..                  ...     ...  ...       ...  ...  ...
# 594   Sound_Cfg_Minus_A    W008    6  0.048357    d  6-8
# 595   Compl_Elm_Minus_A    W008    6  0.048368    d  6-8
# 596   Pictu_Cfg_Minus_A    W008    6  0.047265    d  6-8
# 597   Sound_Cfg_Minus_A    W008    6  0.049932    d  6-8
# 598  Compl_Cfg_Plus__AR    W008    6  0.058137    d  6-8
#
# [599 rows x 6 columns],              Unnamed: 0 subject  run   MISC001 prot time
# 0    Sound_Elm_Plus__AR    W009    2  0.197105    a  0-2
# 1    Compl_Cfg_Plus__AR    W009    2  0.327028    a  0-2
# 2    Sound_Elm_Plus__AR    W009    2  0.329584    a  0-2
# 3    Compl_Cfg_Plus__AR    W009    2  0.335171    a  0-2
# 4     Pictu_Cfg_Minus_A    W009    2  0.339929    a  0-2
# ..                  ...     ...  ...       ...  ...  ...
# 591  Compl_Cfg_Plus__AR    W009    6  0.320758    a  6-8
# 592   Compl_Elm_Minus_A    W009    6  0.257412    a  6-8
# 593   Pictu_Elm_Minus_A    W009    6  0.235832    a  6-8
# 594  Compl_Cfg_Plus__AR    W009    6  0.386913    a  6-8
# 595  Sound_Elm_Plus__AR    W009    6  0.416676    a  6-8
#
# [596 rows x 6 columns],              Unnamed: 0 subject  run   MISC001 prot time
# 0     Pictu_Cfg_Minus_A    W010    2  0.229315    b  0-2
# 1     Sound_Cfg_Minus_A    W010    2  0.256003    b  0-2
# 2     Pictu_Cfg_Minus_A    W010    2  0.264696    b  0-2
# 3     Sound_Elm_Minus_A    W010    2  0.254408    b  0-2
# 4    Pictu_Elm_Plus__AR    W010    2  0.257167    b  0-2
# ..                  ...     ...  ...       ...  ...  ...
# 598  Pictu_Elm_Plus__AR    W010    6  0.183127    b  6-8
# 599   Sound_Elm_Minus_A    W010    6  0.167776    b  6-8
# 600   Pictu_Cfg_Minus_A    W010    6  0.159959    b  6-8
# 601  Pictu_Elm_Plus__AR    W010    6  0.167346    b  6-8
# 602  Compl_Cfg_Plus__AR    W010    6  0.196723    b  6-8
#
# [603 rows x 6 columns],              Unnamed: 0 subject  run   MISC001 prot time
# 0     Sound_Cfg_Minus_A    W011    2  0.253754    c  0-2
# 1     Pictu_Elm_Minus_A    W011    2  0.217150    c  0-2
# 2    Sound_Elm_Plus__AR    W011    2  0.208452    c  0-2
# 3     Pictu_Cfg_Minus_A    W011    2  0.226937    c  0-2
# 4    Sound_Elm_Plus__AR    W011    2  0.187251    c  0-2
# ..                  ...     ...  ...       ...  ...  ...
# 593   Pictu_Elm_Minus_A    W011    6  0.199705    c  6-8
# 594   Sound_Cfg_Minus_A    W011    6  0.191604    c  6-8
# 595  Sound_Elm_Plus__AR    W011    6  0.191539    c  6-8
# 596   Pictu_Cfg_Minus_A    W011    6  0.169134    c  6-8
# 597  Sound_Elm_Plus__AR    W011    6  0.252296    c  6-8
#
# [598 rows x 6 columns],              Unnamed: 0 subject  run   MISC001 prot time
# 0    Pictu_Elm_Plus__AR    W012    2  0.288661    d  0-2
# 1     Compl_Elm_Minus_A    W012    2  0.336603    d  0-2
# 2    Compl_Cfg_Plus__AR    W012    2  0.329943    d  0-2
# 3    Pictu_Elm_Plus__AR    W012    2  0.339794    d  0-2
# 4     Pictu_Cfg_Minus_A    W012    2  0.329543    d  0-2
# ..                  ...     ...  ...       ...  ...  ...
# 594  Compl_Cfg_Plus__AR    W012    6  0.267915    d  6-8
# 595   Pictu_Cfg_Minus_A    W012    6  0.249607    d  6-8
# 596   Sound_Elm_Minus_A    W012    6  0.238761    d  6-8
# 597  Pictu_Elm_Plus__AR    W012    6  0.240494    d  6-8
# 598   Compl_Elm_Minus_A    W012    6  0.234947    d  6-8
#
# [599 rows x 6 columns],              Unnamed: 0 subject  run   MISC001 prot time
# 0     Sound_Cfg_Minus_A    W013    2  0.134700    a  0-2
# 1     Pictu_Elm_Minus_A    W013    2  0.139297    a  0-2
# 2    Sound_Elm_Plus__AR    W013    2  0.138371    a  0-2
# 3     Sound_Cfg_Minus_A    W013    2  0.148568    a  0-2
# 4     Pictu_Cfg_Minus_A    W013    2  0.149711    a  0-2
# ..                  ...     ...  ...       ...  ...  ...
# 592   Pictu_Cfg_Minus_A    W013    6  0.108681    a  6-8
# 593  Compl_Cfg_Plus__AR    W013    6  0.121028    a  6-8
# 594   Pictu_Elm_Minus_A    W013    6  0.113059    a  6-8
# 595   Compl_Elm_Minus_A    W013    6  0.110521    a  6-8
# 596  Sound_Elm_Plus__AR    W013    6  0.115289    a  6-8
#
# [597 rows x 6 columns],              Unnamed: 0 subject  run   MISC001 prot time
# 0    Pictu_Elm_Plus__AR    W014    2  0.135960    b  0-2
# 1    Compl_Cfg_Plus__AR    W014    2  0.214401    b  0-2
# 2     Pictu_Cfg_Minus_A    W014    2  0.219897    b  0-2
# 3     Sound_Cfg_Minus_A    W014    2  0.211298    b  0-2
# 4     Compl_Elm_Minus_A    W014    2  0.205567    b  0-2
# ..                  ...     ...  ...       ...  ...  ...
# 594  Pictu_Elm_Plus__AR    W014    6  0.430183    b  6-8
# 595   Compl_Elm_Minus_A    W014    6  0.324938    b  6-8
# 596  Compl_Cfg_Plus__AR    W014    6  0.378084    b  6-8
# 597   Sound_Elm_Minus_A    W014    6  0.311490    b  6-8
# 598   Pictu_Cfg_Minus_A    W014    6  0.339923    b  6-8
#
# [599 rows x 6 columns]]

# %%
 df = pd.concat([tables[0], tables[1], tables[2], tables[3], tables[4], tables[5], tables[6], tables[7], tables[8], tables[9], tables[10], tables[11], tables[12], tables[13]], axis=0)

# %%
df.to_csv(f'E:/MSUPE/piansrann/table_veg_gsr_15_day1.csv')

# %%
pf = pd.read_csv('E:/MSUPE/piansrann/all8.csv')

# %%
pf

# %%
result = pf.groupby(["subject", "run", "time", "Unnamed: 0"])['MISC001'].mean()
result

# %%
result.to_csv(f'E:/MSUPE/piansrann/all8_grouped.csv')

# %%
result.type()

# %%
plot = result.plot(title="DataFrame Plot")

# %%
df.to_csv(f'E:/MSUPE/piansrann/{subject}.csv')

# %%
result1 = result1.droplevel('epoch')
result1

# %%
df = pd.DataFrame(columns=['subject', 'epoch', 'run', 'MISC001'])

test = pd.concat([df, result2, result3], axis=0)
test

# %%
epochs1

# %%
df = epochs1.to_data_frame()
df

# %%
result = df.groupby(["epoch", "condition"])['MISC001'].mean()
result = result.to_frame()

# %%
result
result.droplevel('epoch')

# %%
result.insert (0, 'run', run)
result.insert (0, 'subject', subject)
result.insert (0, 'time', '-1 - 0')

result

# %%
epochs1.filename
